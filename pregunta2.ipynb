# %%
import os
import csv
import pandas as pd
DF = pd.read_csv('ds_salaries.csv')
DF
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
DF.loc["experience_level", "salary_currency"].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 DF.loc["experience_level", "salary_currency"].describe()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3622, in DataFrame._get_value(self, index, col, takeable)
#    3616 engine = self.index._engine
#    3618 if not isinstance(self.index, MultiIndex):
# ...

# %%
DF.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000
